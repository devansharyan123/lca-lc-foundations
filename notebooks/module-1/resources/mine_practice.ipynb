# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain.chat_models import init_chat_model
model = init_chat_model('deepseek-v4-flash' , extra_body = {
    "thinking" : {
        "type" : "disabled"
    }
})

# %%
from langchain.agents import create_agent
from langchain.messages import HumanMessage , SystemMessage
from pydantic import BaseModel , Field

class Beaches(BaseModel):
    name_of_beach : str
    city  : str
    state : str
    country : str

class BeachesResponse(BaseModel):
    beaches: list[Beaches] = Field(min_length=3, max_length=3)

agent = create_agent(model = model , 
                     system_prompt="You are a travel guide. Return exactly 3 of the most beautiful beaches in the country the user asks for. "
                     ,response_format=BeachesResponse
                     )   

question = HumanMessage(content="What are the most beautiful beaches of the whole world")

response = agent.invoke(
    {"messages" : [question]}
)
response["structured_response"]
# Out:
# BeachesResponse(beaches=[Beaches(name_of_beach='Whitehaven Beach', city='Whitsunday Island', state='Queensland', country='Australia'), Beaches(name_of_beach="Anse Source d'Argent", city='La Digue', state='', country='Seychelles'), Beaches(name_of_beach='Navagio Beach (Shipwreck Beach)', city='Zakynthos', state='Ionian Islands', country='Greece')])

# %%
index = response["structured_response"]

for beach in index.beaches:
    print(beach.name_of_beach + " : " + beach.city + " , " + beach.country)
# Out:
# Whitehaven Beach : Whitsunday Island , Australia
# Anse Source d'Argent : La Digue , Seychelles
# Navagio Beach (Shipwreck Beach) : Zakynthos , Greece
