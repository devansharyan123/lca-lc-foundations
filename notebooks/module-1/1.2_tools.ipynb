# %% [markdown]
# ## Tool definition

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain.chat_models import init_chat_model

model = init_chat_model('deepseek-v4-flash' , extra_body = {
    "thinking" : {
        "type" : "disabled"
    }
})

# %%
from langchain.tools import tool

@tool
def square_root(x: float) -> float:
    """Calculate the square root of a number"""
    return x ** 0.5

# %%
@tool("square_root")
def tool1(x: float) -> float:
    """Calculate the square root of a number"""
    return x ** 0.5

# %%
from langchain.tools import tool

@tool("square_root", description="Calculate the square root of a number")
def tool1(x: float) -> float:
    return x ** 0.5

# %%
square_root.invoke({"x": 400})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 square_root.invoke({"x": 400})
#
# NameError: name 'square_root' is not defined

# %% [markdown]
# ## Adding to agents

# %%
from langchain.agents import create_agent

agent = create_agent(
    model=model,
    tools=[tool1],
    system_prompt="You are an arithmetic wizard. Use your tools to calculate the square root and square of any number."
)

# %%
from langchain.messages import HumanMessage

question = HumanMessage(content="What is the square root of 467?")

response = agent.invoke(
    {"messages": [question]}
)

print(response['messages'][-1].content)
# Out:
# The square root of **467** is approximately **21.6102** (rounded to 4 decimal places).
#
# To double-check, let's also calculate its square:
#
# \[
# 21.61018278497431^2 \approx 467
# \]

# %%
from pprint import pprint

pprint(response['messages'])
# Out:
# [HumanMessage(content='What is the square root of 467?', additional_kwargs={}, response_metadata={}, id='129e0575-70cf-403f-b1a6-d9df7038798f'),
#  AIMessage(content='Let me calculate the square root of 467 for you.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 55, 'prompt_tokens': 302, 'total_tokens': 357, 'completion_tokens_details': None, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 256}, 'prompt_cache_hit_tokens': 256, 'prompt_cache_miss_tokens': 46}, 'model_provider': 'deepseek', 'model_name': 'deepseek-v4-flash', 'system_fingerprint': 'fp_8b330d02d0_prod0820_fp8_kvcache_20260402', 'id': '36a92ea5-aacb-44a2-b89f-9bebe0db4538', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019e6a0f-d967-7170-bab9-2bae2c849cb8-0', tool_calls=[{'name': 'square_root', 'args': {'x': 467}, 'id': 'call_00_bSjtmwtFSNXyhKOITKcn9699', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 302, 'output_tokens': 55, 'total_tokens': 357, 'input_token_details': {'cache_read': 256}, 'output_token_details': {}}),
#  ToolMessage(content='21.61018278497431', name='square_root', id='4d275af6-0951-48b4-b64b-68e1664bad7d', tool_call_id='call_00_bSjtmwtFSNXyhKOITKcn9699'),
#  AIMessage(content="The square root of **467** is approximately **21.6102** (rounded to 4 decimal places).\n\nTo double-check, let's also calculate its square:\n\n\\[\n21.61018278497431^2 \\approx 467\n\\]", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 51, 'prompt_tokens': 375, 'total_tokens': 426, 'completion_tokens_details': None, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 256}, 'prompt_cache_hit_tokens': 256, 'prompt_cache_miss_tokens': 119}, 'model_provider': 'deepseek', 'model_name': 'deepseek-v4-flash', 'system_fingerprint': 'fp_8b330d02d0_prod0820_fp8_kvcache_20260402', 'id': '561b1c28-5fdc-4e7a-92a8-2761027bcaa7', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019e6a0f-de08-7e10-972a-fbfeead65cdb-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 375, 'output_tokens': 51, 'total_tokens': 426, 'input_token_details': {'cache_read': 256}, 'output_token_details': {}})]

# %%
print(response["messages"][1].tool_calls)
# Out:
# [{'name': 'square_root', 'args': {'x': 467}, 'id': 'call_00_bSjtmwtFSNXyhKOITKcn9699', 'type': 'tool_call'}]
