# %% [markdown]
# ## Without web search

# %%
from dotenv import load_dotenv


load_dotenv()
# Out:
# True

# %%
from langchain.chat_models import init_chat_model

model = init_chat_model('deepseek-v4-flash' ,  extra_body={
        "thinking": {
            "type": "disabled"
        }
    })

# %%
from langchain.agents import create_agent

agent = create_agent(
    model=model
)

# %%
from langchain.messages import HumanMessage

question = HumanMessage(content="How up to date is your training knowledge?")

response = agent.invoke(
    {"messages": [question]}
)

# %%
print(response['messages'][-1].content)
# Out:
# Great question! My training data has a cutoff date of **May 2025**, so I have knowledge of events, technologies, and information up to that point.
#
# Beyond that date, I don't have any real-time awareness — meaning I can't know about things that happened after May 2025 unless I'm browsing the internet (if that feature is enabled by your platform).
#
# If you need the very latest updates or breaking news, I’d recommend searching online or enabling my web search functionality if it’s available in our current setup.
#
# Is there a specific topic or time-sensitive question you’re curious about? I’d be happy to help with what I know or point you in the right direction!

# %% [markdown]
# ## Add web search tool

# %%
from langchain.tools import tool
from typing import Dict, Any
from tavily import TavilyClient

tavily_client = TavilyClient()

@tool
def web_search(query: str) -> Dict[str, Any]:

    """Search the web for information"""

    return tavily_client.search(query)

web_search.invoke("Who is the current cm of West Bengal?")
# Out:
# {'query': 'Who is the current cm of West Bengal?',
#  'follow_up_questions': None,
#  'answer': None,
#  'images': [],
#  'results': [{'url': 'https://www.facebook.com/BanglarGorboMamata/posts/cm-of-bengal-mamatabanerjee-/1197491022563317',
#    'title': 'CM of Bengal #MamataBanerjee - Facebook',
#    'content': "Bengal CM Mamata Banerjee 's impressive ranking as the second-best Chief Minister in India Today's 'Mood of the Nation' survey is a testament to",
#    'score': 0.9954261,
#    'raw_content': None},
#   {'url': 'https://www.facebook.com/PMOIndia/posts/west-bengal-cm-mamata-banerjee-met-pm-narendra-modi/430354209127739',
#    'title': 'West Bengal CM Mamata Banerjee met PM Narendra Modi',
#    'content': 'Mr Prime Minister Greetings! When you have given a call to celebrate Azadi Ka Mahotsav you should have especially taken an initiative to',
#    'score': 0.99351174,
#    'raw_content': None},
#   {'url': 'https://www.youtube.com/watch?v=h9b5l12y5IA',
#    'title': "Mamata Banerjee Refuses To Step Down As CM, Says 'I ... - YouTube",
#    'content': 'breakingnews | Mamata Banerjee has refused to step down as Chief Minister of West Bengal, asserting, “I have not lost.',
#    'score': 0.98173577,
#    'raw_content': None},
#   {'url': 'https://en.wikipedia.org/wiki/Mamata_Banerjee',
#    'title': 'Mamata Banerjee - Wikipedia',
#    'content': 'Mamata Banerjee is an Indian politician and lawyer who served as the eighth chief minister of West Bengal from 2011 to 2026. She was the first woman to hold',
#    'score': 0.41111085,
#    'raw_content': None},
#   {'url': 'https://en.wikipedia.org/wiki/Chief_Minister_of_West_Bengal',
#    'title': 'Chief Minister of West Bengal - Wikipedia',
#    'content': 'The Chief Minister of West Bengal (ISO: Paścimabaṅgera Mukhyamantrī) is the de facto head of the executive branch of the Government of West Bengal,',
#    'score': 0.15405756,
#    'raw_content': None}],
#  'response_time': 1.32,
#  'request_id': '59b5a1d3-3362-407b-acdb-f89f337ecbb6'}

# %%
agent = create_agent(
    model=model,
    tools=[web_search]
)

question = HumanMessage(content="Who is the new chief minister of west bengal")

response = agent.invoke(
    {"messages": [question]}
)

# %%
from pprint import pprint

pprint(response['messages'][-1].content)
# Out:
# ('Based on the latest information, the new Chief Minister of West Bengal is '
#  '**Suvendu Adhikari** of the Bharatiya Janata Party (BJP). He was sworn in on '
#  '**May 9, 2026**, after the BJP won the 2026 West Bengal Legislative Assembly '
#  "election, defeating Mamata Banerjee's Trinamool Congress (TMC), which had "
#  'been in power for 15 years.\n'
#  '\n'
#  'Key details:\n'
#  '- He is the **9th Chief Minister of West Bengal** and the **first BJP Chief '
#  'Minister** of the state.\n'
#  '- He replaced **Mamata Banerjee**, who had been Chief Minister since 2011.\n'
#  '- He previously served as the Leader of the Opposition in the West Bengal '
#  'Legislative Assembly (2021–2026) and was a minister in the TMC government '
#  'before switching to the BJP.')

# %% [markdown]
# trace: https://smith.langchain.com/public/59432173-0dd6-49e8-9964-b16be6048426/r
